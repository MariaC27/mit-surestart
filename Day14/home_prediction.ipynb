# %%
#read in and process data
import pandas as pd
df = pd.read_csv('housepricedata.csv')
df
# Out:
#       LotArea  OverallQual  OverallCond  TotalBsmtSF  FullBath  HalfBath  \
# 0        8450            7            5          856         2         1
# 1        9600            6            8         1262         2         0
# 2       11250            7            5          920         2         1
# 3        9550            7            5          756         1         0
# 4       14260            8            5         1145         2         1
# ...       ...          ...          ...          ...       ...       ...
# 1455     7917            6            5          953         2         1
# 1456    13175            6            6         1542         2         0
# 1457     9042            7            9         1152         2         0
# 1458     9717            5            6         1078         1         0
# 1459     9937            5            6         1256         1         1
#
#       BedroomAbvGr  TotRmsAbvGrd  Fireplaces  GarageArea  AboveMedianPrice
# 0                3             8           0         548                 1
# 1                3             6           1         460                 1
# 2                3             6           1         608                 1
# 3                3             7           1         642                 0
# 4                4             9           1         836                 1
# ...            ...           ...         ...         ...               ...
# 1455             3             7           1         460                 1
# 1456             3             7           2         500                 1
# 1457             4             9           2         252                 1
# 1458             2             5           0         240                 0
# 1459             3             6           0         276                 0
#
# [1460 rows x 11 columns]

# %%
dataset = df.values
#converts datagrame into array
dataset
# Out:
# array([[ 8450,     7,     5, ...,     0,   548,     1],
#        [ 9600,     6,     8, ...,     1,   460,     1],
#        [11250,     7,     5, ...,     1,   608,     1],
#        ...,
#        [ 9042,     7,     9, ...,     2,   252,     1],
#        [ 9717,     5,     6, ...,     0,   240,     0],
#        [ 9937,     5,     6, ...,     0,   276,     0]], dtype=int64)

# %%
#split dataset into input features and predictions
#first 10 columns are inputs and last columns is predictions
X = dataset[:, 0:10]
Y = dataset[:, 10]

# %%
from sklearn import preprocessing
#scale the dataset so all the input features are 
#between 0 and 1
min_max_scaler = preprocessing.MinMaxScaler()
X_scale = min_max_scaler.fit_transform(X)

# %%
#now split data into training set, validation set, test set
#separate training set from validation+test
from sklearn.model_selection import train_test_split
X_train, X_val_and_test, Y_train, Y_val_and_test = train_test_split(X_scale, Y, test_size=0.3)

#then separate validation and test set
X_val, X_test, Y_val, Y_test = train_test_split(X_val_and_test, Y_val_and_test, test_size=0.5)

print(X_train.shape, X_val.shape, X_test.shape, Y_train.shape, Y_val.shape, Y_test.shape)
# Out:
# (1022, 10) (219, 10) (219, 10) (1022,) (219,) (219,)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
import tensorflow.keras.utils

#define model architecture
model = Sequential([
    #first layer, dense layer with 32 neurons and relu activation
    #"Dense" refers to a fully connected layer
    Dense(32, activation='relu', input_shape=(10,)),
    
    #second layer is also a fully connected layer
    Dense(32, activation='relu'),
    
    #third layer has sigmoid activation
    Dense(1, activation='sigmoid'),
])

# %%
#configure the model - stochastic gradient descent optimizer
model.compile(optimizer='sgd',
              loss='binary_crossentropy',
              metrics=['accuracy'])

# %%
#train the model!
hist = model.fit(X_train, Y_train,
          batch_size=32, epochs=100,
          validation_data=(X_val, Y_val))
# Out:
# Epoch 1/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.6757 - accuracy: 0.6830 - val_loss: 0.6699 - val_accuracy: 0.7580
# Epoch 2/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.6682 - accuracy: 0.7916 - val_loss: 0.6651 - val_accuracy: 0.7991
# Epoch 3/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.6617 - accuracy: 0.8063 - val_loss: 0.6602 - val_accuracy: 0.8128
# Epoch 4/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.6557 - accuracy: 0.8053 - val_loss: 0.6554 - val_accuracy: 0.8037
# Epoch 5/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.6499 - accuracy: 0.7984 - val_loss: 0.6501 - val_accuracy: 0.7900
# Epoch 6/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.6440 - accuracy: 0.7867 - val_loss: 0.6440 - val_accuracy: 0.8082
# Epoch 7/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.6380 - accuracy: 0.8219 - val_loss: 0.6389 - val_accuracy: 0.7900
# Epoch 8/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.6319 - accuracy: 0.8053 - val_loss: 0.6327 - val_accuracy: 0.7991
# Epoch 9/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.6255 - accuracy: 0.8063 - val_loss: 0.6258 - val_accuracy: 0.8037
# Epoch 10/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.6188 - accuracy: 0.8151 - val_loss: 0.6187 - val_accuracy: 0.8174
# Epoch 11/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.6117 - accuracy: 0.8219 - val_loss: 0.6115 - val_accuracy: 0.8082
# Epoch 12/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.6042 - accuracy: 0.8297 - val_loss: 0.6041 - val_accuracy: 0.8082
# Epoch 13/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.5965 - accuracy: 0.8297 - val_loss: 0.5962 - val_accuracy: 0.8128
# Epoch 14/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.5885 - accuracy: 0.8297 - val_loss: 0.5876 - val_accuracy: 0.8128
# Epoch 15/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.5802 - accuracy: 0.8356 - val_loss: 0.5786 - val_accuracy: 0.8265
# Epoch 16/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.5715 - accuracy: 0.8376 - val_loss: 0.5690 - val_accuracy: 0.8356
# Epoch 17/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.5626 - accuracy: 0.8513 - val_loss: 0.5601 - val_accuracy: 0.8311
# Epoch 18/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.5537 - accuracy: 0.8464 - val_loss: 0.5498 - val_accuracy: 0.8402
# Epoch 19/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.5445 - accuracy: 0.8552 - val_loss: 0.5409 - val_accuracy: 0.8356
# Epoch 20/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.5350 - accuracy: 0.8464 - val_loss: 0.5299 - val_accuracy: 0.8539
# Epoch 21/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.5256 - accuracy: 0.8562 - val_loss: 0.5178 - val_accuracy: 0.8584
# Epoch 22/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.5162 - accuracy: 0.8601 - val_loss: 0.5082 - val_accuracy: 0.8630
# Epoch 23/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.5063 - accuracy: 0.8611 - val_loss: 0.4959 - val_accuracy: 0.8630
# Epoch 24/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.4967 - accuracy: 0.8630 - val_loss: 0.4882 - val_accuracy: 0.8630
# Epoch 25/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.4871 - accuracy: 0.8601 - val_loss: 0.4774 - val_accuracy: 0.8676
# Epoch 26/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.4777 - accuracy: 0.8630 - val_loss: 0.4668 - val_accuracy: 0.8676
# Epoch 27/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.4685 - accuracy: 0.8640 - val_loss: 0.4574 - val_accuracy: 0.8676
# Epoch 28/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.4596 - accuracy: 0.8650 - val_loss: 0.4475 - val_accuracy: 0.8676
# Epoch 29/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.4511 - accuracy: 0.8669 - val_loss: 0.4391 - val_accuracy: 0.8676
# Epoch 30/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.4432 - accuracy: 0.8650 - val_loss: 0.4302 - val_accuracy: 0.8676
# Epoch 31/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.4350 - accuracy: 0.8669 - val_loss: 0.4192 - val_accuracy: 0.8630
# Epoch 32/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.4278 - accuracy: 0.8659 - val_loss: 0.4098 - val_accuracy: 0.8630
# Epoch 33/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.4206 - accuracy: 0.8611 - val_loss: 0.4042 - val_accuracy: 0.8630
# Epoch 34/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.4136 - accuracy: 0.8650 - val_loss: 0.3965 - val_accuracy: 0.8630
# Epoch 35/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.4073 - accuracy: 0.8669 - val_loss: 0.3881 - val_accuracy: 0.8630
# Epoch 36/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.4007 - accuracy: 0.8689 - val_loss: 0.3844 - val_accuracy: 0.8676
# Epoch 37/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.3957 - accuracy: 0.8659 - val_loss: 0.3740 - val_accuracy: 0.8676
# Epoch 38/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.3899 - accuracy: 0.8620 - val_loss: 0.3697 - val_accuracy: 0.8676
# Epoch 39/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.3852 - accuracy: 0.8669 - val_loss: 0.3616 - val_accuracy: 0.8676
# Epoch 40/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.3803 - accuracy: 0.8630 - val_loss: 0.3575 - val_accuracy: 0.8721
# Epoch 41/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.3759 - accuracy: 0.8611 - val_loss: 0.3532 - val_accuracy: 0.8676
# Epoch 42/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.3715 - accuracy: 0.8611 - val_loss: 0.3473 - val_accuracy: 0.8721
# Epoch 43/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.3677 - accuracy: 0.8640 - val_loss: 0.3405 - val_accuracy: 0.8767
# Epoch 44/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.3635 - accuracy: 0.8659 - val_loss: 0.3388 - val_accuracy: 0.8721
# Epoch 45/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.3603 - accuracy: 0.8611 - val_loss: 0.3334 - val_accuracy: 0.8767
# Epoch 46/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.3569 - accuracy: 0.8630 - val_loss: 0.3315 - val_accuracy: 0.8721
# Epoch 47/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.3546 - accuracy: 0.8640 - val_loss: 0.3253 - val_accuracy: 0.8813
# Epoch 48/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.3519 - accuracy: 0.8659 - val_loss: 0.3223 - val_accuracy: 0.8813
# Epoch 49/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.3489 - accuracy: 0.8650 - val_loss: 0.3189 - val_accuracy: 0.8813
# Epoch 50/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.3466 - accuracy: 0.8669 - val_loss: 0.3155 - val_accuracy: 0.8813
# Epoch 51/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.3445 - accuracy: 0.8640 - val_loss: 0.3124 - val_accuracy: 0.8813
# Epoch 52/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.3427 - accuracy: 0.8659 - val_loss: 0.3087 - val_accuracy: 0.8767
# Epoch 53/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.3400 - accuracy: 0.8669 - val_loss: 0.3052 - val_accuracy: 0.8813
# Epoch 54/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.3379 - accuracy: 0.8718 - val_loss: 0.3062 - val_accuracy: 0.8858
# Epoch 55/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.3363 - accuracy: 0.8669 - val_loss: 0.3019 - val_accuracy: 0.8767
# Epoch 56/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.3343 - accuracy: 0.8650 - val_loss: 0.2969 - val_accuracy: 0.8858
# Epoch 57/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.3325 - accuracy: 0.8630 - val_loss: 0.2946 - val_accuracy: 0.8904
# Epoch 58/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.3308 - accuracy: 0.8728 - val_loss: 0.2957 - val_accuracy: 0.8767
# Epoch 59/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.3300 - accuracy: 0.8708 - val_loss: 0.2924 - val_accuracy: 0.8813
# Epoch 60/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.3281 - accuracy: 0.8679 - val_loss: 0.2896 - val_accuracy: 0.8904
# Epoch 61/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.3261 - accuracy: 0.8738 - val_loss: 0.2865 - val_accuracy: 0.8904
# Epoch 62/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.3262 - accuracy: 0.8718 - val_loss: 0.2855 - val_accuracy: 0.8904
# Epoch 63/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.3236 - accuracy: 0.8728 - val_loss: 0.2834 - val_accuracy: 0.8904
# Epoch 64/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.3218 - accuracy: 0.8787 - val_loss: 0.2864 - val_accuracy: 0.8813
# Epoch 65/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.3213 - accuracy: 0.8738 - val_loss: 0.2820 - val_accuracy: 0.8904
# Epoch 66/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.3197 - accuracy: 0.8748 - val_loss: 0.2843 - val_accuracy: 0.8813
# Epoch 67/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.3195 - accuracy: 0.8748 - val_loss: 0.2790 - val_accuracy: 0.8950
# Epoch 68/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.3173 - accuracy: 0.8767 - val_loss: 0.2747 - val_accuracy: 0.8950
# Epoch 69/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.3171 - accuracy: 0.8738 - val_loss: 0.2742 - val_accuracy: 0.8950
# Epoch 70/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.3152 - accuracy: 0.8718 - val_loss: 0.2759 - val_accuracy: 0.8950
# Epoch 71/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.3143 - accuracy: 0.8767 - val_loss: 0.2712 - val_accuracy: 0.8950
# Epoch 72/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.3139 - accuracy: 0.8777 - val_loss: 0.2720 - val_accuracy: 0.8950
# Epoch 73/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.3122 - accuracy: 0.8728 - val_loss: 0.2690 - val_accuracy: 0.8950
# Epoch 74/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.3118 - accuracy: 0.8767 - val_loss: 0.2680 - val_accuracy: 0.8950
# Epoch 75/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.3109 - accuracy: 0.8738 - val_loss: 0.2698 - val_accuracy: 0.8950
# Epoch 76/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.3101 - accuracy: 0.8767 - val_loss: 0.2666 - val_accuracy: 0.8950
# Epoch 77/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.3091 - accuracy: 0.8748 - val_loss: 0.2649 - val_accuracy: 0.8950
# Epoch 78/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.3077 - accuracy: 0.8767 - val_loss: 0.2632 - val_accuracy: 0.8950
# Epoch 79/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.3071 - accuracy: 0.8796 - val_loss: 0.2615 - val_accuracy: 0.8995
# Epoch 80/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.3064 - accuracy: 0.8806 - val_loss: 0.2630 - val_accuracy: 0.8995
# Epoch 81/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.3054 - accuracy: 0.8796 - val_loss: 0.2610 - val_accuracy: 0.8950
# Epoch 82/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.3044 - accuracy: 0.8767 - val_loss: 0.2608 - val_accuracy: 0.8995
# Epoch 83/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.3033 - accuracy: 0.8777 - val_loss: 0.2585 - val_accuracy: 0.8950
# Epoch 84/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.3028 - accuracy: 0.8787 - val_loss: 0.2582 - val_accuracy: 0.8950
# Epoch 85/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.3017 - accuracy: 0.8806 - val_loss: 0.2597 - val_accuracy: 0.8995
# Epoch 86/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.3017 - accuracy: 0.8806 - val_loss: 0.2565 - val_accuracy: 0.8950
# Epoch 87/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.3007 - accuracy: 0.8816 - val_loss: 0.2582 - val_accuracy: 0.8995
# Epoch 88/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.3002 - accuracy: 0.8806 - val_loss: 0.2543 - val_accuracy: 0.8995
# Epoch 89/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.2990 - accuracy: 0.8816 - val_loss: 0.2538 - val_accuracy: 0.8950
# Epoch 90/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.2987 - accuracy: 0.8845 - val_loss: 0.2532 - val_accuracy: 0.8950
# Epoch 91/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.2978 - accuracy: 0.8865 - val_loss: 0.2524 - val_accuracy: 0.8950
# Epoch 92/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.2966 - accuracy: 0.8816 - val_loss: 0.2497 - val_accuracy: 0.8995
# Epoch 93/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.2969 - accuracy: 0.8855 - val_loss: 0.2508 - val_accuracy: 0.8950
# Epoch 94/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.2960 - accuracy: 0.8845 - val_loss: 0.2503 - val_accuracy: 0.8950
# Epoch 95/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.2947 - accuracy: 0.8845 - val_loss: 0.2522 - val_accuracy: 0.8995
# Epoch 96/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.2945 - accuracy: 0.8836 - val_loss: 0.2497 - val_accuracy: 0.8995
# Epoch 97/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.2939 - accuracy: 0.8865 - val_loss: 0.2493 - val_accuracy: 0.8995
# Epoch 98/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.2927 - accuracy: 0.8845 - val_loss: 0.2454 - val_accuracy: 0.8995
# Epoch 99/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.2929 - accuracy: 0.8894 - val_loss: 0.2452 - val_accuracy: 0.8995
# Epoch 100/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.2913 - accuracy: 0.8875 - val_loss: 0.2484 - val_accuracy: 0.8995

# %%
#find the accuracy on the test set
#model.evaluate returns loss as first element (0) and 
#accuracy as second element (1), so specify 1 in brackets
model.evaluate(X_test, Y_test)[1]
# Out:
# 7/7 [==============================] - 0s 495us/step - loss: 0.2643 - accuracy: 0.8858
# 0.8858447670936584

# %%
#visualizing loss and accuracy
import matplotlib.pyplot as plt
plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Val'], loc='upper right')
plt.show()

plt.plot(hist.history['accuracy']) #use "accuracy" instead of acc
plt.plot(hist.history['val_accuracy']) #same as previous line
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Val'], loc='lower right')
plt.show()
