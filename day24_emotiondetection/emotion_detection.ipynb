# %%
from fer import FER
import matplotlib.pyplot as plt 
img = plt.imread("mariacristoforo.jpeg")
detector = FER(mtcnn=True)
print(detector.detect_emotions(img))
plt.imshow(img)
# Out:
# [{'box': (280, 466, 1204, 1204), 'emotions': {'angry': 0.0, 'disgust': 0.0, 'fear': 0.01, 'happy': 0.97, 'sad': 0.0, 'surprise': 0.0, 'neutral': 0.01}}]
